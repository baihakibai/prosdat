# %%
pip install bs4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: bs4 in /usr/local/lib/python3.8/dist-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from bs4) (4.6.3)

# %%
import requests as req
from bs4 import BeautifulSoup as bs
from datetime import datetime
import csv
hades = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36'}

# %%
def scrape_detik(hal):
    global hades
    a = 1
    for page in range(1,hal):
        url = f'https://www.detik.com/search/searchall?query=bjorka&siteid={page}'
        ge = req.get(url,hades).text
        sop = bs(ge,'lxml')
        li = sop.find('div',class_='list media_rows list-berita')
        lin = li.find_all('article')
        for x in lin:
            link = x.find('a')['href']
            date = x.find('a').find('span',class_='date').text.replace('WIB','').replace('detikNews','').split(',')[1]
            headline = x.find('a').find('h2').text
            ge_ = req.get(link,hades).text
            sop_ = bs(ge_,'lxml')
            content = sop_.find_all('div',class_='detail__body-text itp_bodycontent')
            for x in content:
                x = x.find_all('p')
                y  = [y.text for y in x ]
                content_ = ''.join(y).replace('\n', '').replace('ADVERTISEMENT','').replace('SCROLL TO RESUME CONTENT','')
                print(f'done[{a}] > {headline[0:100]}')
                a += 1
                with open('sambo_detik.csv','a')as file:
                    wr = csv.writer(file, delimiter=',')
                    wr.writerow([headline,date,link,content_])

# %%
scrape_detik(120)
# Out:
# done[1] > Kilas Balik Aksi Bjorka Curi-curi Data, Dijual Demi Cuan!
# done[2] > September: Santri Gontor Tewas Dianiaya-Pemuda Madiun Tersangka Bjorka
# done[3] > Perlindungan Data dan Inklusi (Keuangan) Digital
# done[4] > Situs PN Jakpus Diretas, Hacker Bawa-bawa Bjorka hingga Kasus Sambo
# done[5] > Kepala BIN Ogah Bicara soal Bjorka dan Kebocoran Data Internal
# done[6] > Komisi I DPR dan BIN Rapat Tertutup, Bahas Keamanan Siber-Data Pemilu
# done[7] > Situs Pemprov Sultra Dibajak, Hacker Bawa-bawa Bjorka
# done[8] > Respons Polri soal Dugaan 26 Juta Data Polisi Bocor: Sudah Usang
# done[9] > Polri Tegaskan Isu Kebocoran 26 Juta Data Anggota Polisi Hoax!
# done[10] > Kilas Balik Aksi Bjorka Curi-curi Data, Dijual Demi Cuan!
# done[11] > Datanya Diincaran Bjorka, Aplikasi MyPertamina Jadi Dipakai Nggak Sih?
# done[12] > Bos Amman Mineral Beberkan Kronologi Kecelakaan Maut di Lokasi Tambang
# done[13] > Bjorka Jual 44 Juta Data Diduga MyPertamina, Telkom & Pertamina Investigasi
# done[14] > Bjorka Muncul Lagi, 44 Juta Data MyPertamina Dijual Rp 392 Juta!
# done[15] > Luhut Ngaku Sudah 5 Kali Vaksin Booster
# done[16] > Podcast: Bongkar Potensi 'Bisnis' Data Ala Bjorka (ft. Ruby Alamsyah)
# done[17] > Aksi Bjorka cs Bikin Resah, Data Wajib Pajak Aman Nggak Sih?
# done[18] > Mudah Dicuri, Data Orang Indonesia Dihargai 1 Rupiah
# done[19] > YouTuber Cilik Pipil Memburu Hacker di Web Series
# done[20] > Asal Mula 'Wajah' Bjorka
# done[21] > Nikita Mirzani Serang Bjorka: Hacker Apa Tukang Ngarang?
# done[55] > Bjorka Beraksi Lagi, Kali Ini Bocorkan Data Diduga MyPertamina
# done[56] > Bjorka Umbar Data Pribadi Menpora di Tengah Tragedi Kanjuruhan
# done[57] > Pengakuan Pemuda Madiun saat Dicecar Pertanyaan Polisi Seputar Bjorka
# done[58] > Sindiran Menohok Mahfud Md Buat Bjorka: Tak Ada Apa-Apanya-Cuma Ngarang
# done[59] > Pemerintah Bakal Buat Peraturan untuk Penguatan Sistem Cyber di Daerah
# done[60] > Bingung Cairkan Bitcoin dari Bjorka, Pemuda Madiun Belajar Lewat YouTube
# done[61] > Mahfud Md Sebut Bjorka Salah Tulis Nama Ibunya: Ngarang Dia
# done[62] > Mahfud MD Tegaskan Data Negara Tak Bocor: Itu Bjorka Ndak Ada Apa-Apanya!

# %%
import pandas as pd
df = pd.read_csv('/content/sambo_detik.csv')
df
# Out:
#    Kilas Balik Aksi Bjorka Curi-curi Data, Dijual Demi Cuan!  \
# 0   September: Santri Gontor Tewas Dianiaya-Pemuda...
# 1    Perlindungan Data dan Inklusi (Keuangan) Digital
# 2   Situs PN Jakpus Diretas, Hacker Bawa-bawa Bjor...
# 3   Kepala BIN Ogah Bicara soal Bjorka dan Kebocor...
# 4   Komisi I DPR dan BIN Rapat Tertutup, Bahas Kea...
# ..                                                ...
# 56  Sindiran Menohok Mahfud Md Buat Bjorka: Tak Ad...
# 57  Pemerintah Bakal Buat Peraturan untuk Penguata...
# 58  Bingung Cairkan Bitcoin dari Bjorka, Pemuda Ma...
# 59  Mahfud Md Sebut Bjorka Salah Tulis Nama Ibunya...
# 60  Mahfud MD Tegaskan Data Negara Tak Bocor: Itu ...
#
#      11 Jan 2023 06:00   \
# 0    28 Des 2022 14:36
# 1    15 Des 2022 10:29
# 2    05 Okt 2022 09:10
# 3    26 Sep 2022 22:12
# 4    26 Sep 2022 17:48
# ..                  ...
# 56   22 Sep 2022 07:03
# 57   21 Sep 2022 21:59
# 58   21 Sep 2022 19:56
# 59   21 Sep 2022 14:40
# 60   21 Sep 2022 14:06
#
#    https://finance.detik.com/berita-ekonomi-bisnis/d-6508922/kilas-balik-aksi-bjorka-curi-curi-data-dijual-demi-cuan  \
# 0   https://www.detik.com/jatim/berita/d-6485538/s...
# 1   https://news.detik.com/kolom/d-6462532/perlind...
# 2   https://news.detik.com/berita/d-6329880/situs-...
# 3   https://news.detik.com/berita/d-6313958/kepala...
# 4   https://news.detik.com/berita/d-6313562/komisi...
# ..                                                ...
# 56  https://www.detik.com/jatim/berita/d-6305150/s...
# 57  https://www.detik.com/jatim/berita/d-6305015/p...
# 58  https://www.detik.com/jatim/berita/d-6304878/b...
# 59  https://www.detik.com/jatim/berita/d-6304052/m...
# 60  https://www.detik.com/jatim/berita/d-6303967/m...
#
#    Munculnya hacker Bjorka Agustus 2022 lalu bikin geger masyarakat. Bjorka mengklaim berhasil membobol data-data penting, lalu menjualnya di internet.Beberapa data yang diduga dibobol Bjorka antara lain Nomor Induk Kependudukan (NIK), nama lengkap, alamat rumah, dosis vaksin, hingga nomor HP. Data tersebut dicuri dari sejumlah instansi.Bjorka menyebarkan data itu lewat channel pribadinya di telegram. Bukan cuma data-data penting tadi beberapa pejabat dan tokoh-tokoh publik juga ikut disenggol Bjorka.\r    \r  \r        \r  Aksi curi-curi data oleh Bjorka membuat Otoritas Jasa Keuangan (OJK) buka suara. OJK mewanti-wanti lembaga keuangan menjaga data-data bisnis dan nasabahnya.Kepala Eksekutif Pengawas IKNB OJK Ogi Prastomiyono mengingatkan dunia digital dari waktu ke waktu semakin canggih. Potensi kebocoran data bisa terjadi kapan saja.Dalam catatan detikcom, berikut sederet aksi Bjorka yang sempat bikin heboh:Melansir dari detikinet, Bjorka mengklaim telah mengantongi 26 juta history browsing pelanggan IndiHome. Data yang dicuri mencakup keyword, email, jenis kelamin, NIK hingga nama.Namun perwakilan Telkom Group menyatakan, bahwa data-data yang bocor tidak valid dan merupakan hasil fabrikasi. Menurut Ahmad Reza, SVP Corporate Communication & Investor Relation Telkom, Telkom tidak menggunakan email @telkom.net, baik untuk kepentingan perusahaan maupun layanan bagi pelanggan.Lanjutnya, Reza mengatakan kalau format telkom.net ini, digunakan Telkom sebagai domain atau user id IndiHome. Lalu ia mengatakan bahwa tidak ada sistem di Telkom yang menyimpan browsing history dan data pribadi, secara berdampingan.Bjorka selanjutnya membocorkan yang diduga data registrasi SIM Card Prabayar. Sang hacker mengungkapkan, memiliki 1,3 miliar data yang berukuran 87GB. Di dalamnya berisi NIK, nomor telepon, operator seluler, dan tanggal registrasi.Harga yang dibanderol Bjorka untuk data ini adalah US$ 50 ribu atau sekitar Rp 780 juta (kurs Rp 15.600).Dari mana sebenarnya sumber data itu berasal? Dirjen Aptika Kementerian Kominfo, Semuel Abrijani Pangerapan menyampaikan, Ditjen PPI Kementerian Kominfo hanya menyimpan data SIM Card dalam bentuk agregat, seperti seberapa banyak pelanggan aktif di operator seluler.Ia memaparkan, ketika pelanggan melakukan pendaftaran nomor telepon prabayar, maka data seperti NIK dan nomor KK, itu masuk ke operator.
# 0   Selama Bulan September 2022, ada beberapa beri...
# 1   Dewan Perwakilan Rakyat (DPR) telah mengesahka...
# 2   Situs Pengadilan Negeri Jakarta Pusat (PN Jakp...
# 3   Kepala Badan Intelijen Negara (BIN) Budi Gunaw...
# 4   Komisi I DPR menggelar rapat bersama Badan Int...
# ..                                                ...
# 56  Hacker Bjorka telah membuat jagat Twitter dan ...
# 57  Kepala Staf Kepresidenan Moeldoko mengatakan b...
# 58  Muhammad Agung Hidayatullah alias MAH telah di...
# 59  Menkopolhukam Mahfud Md memastikan tak data ne...
# 60  Menkopolhukam Mahfud MD menegaskan hacker Bjor...
#
# [61 rows x 4 columns]
