# %% [markdown]
# # Crawling twitter

# %%
# !pip install snscrape
'''
digunakan untuk menginstall library snscrape, digunakan untuk mengambil data(sraping) dari sosial media, seperti twitter
'''
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.8/71.8 kB 4.4 MB/s eta 0:00:00
# ...
# '\ndigunakan untuk menginstall library snscrape, digunakan untuk mengambil data(sraping) dari sosial media, seperti twitter\n'

# %%
import pandas as pd
from tqdm.notebook import tqdm
from ipywidgets import FloatProgress
import snscrape.modules.twitter as sntwitter

# %%
scraper=sntwitter.TwitterSearchScraper("pildun22")
tweets=[]
n_tweets=500
for i, tweet in tqdm(enumerate(scraper.get_items()), total=n_tweets):
    data=[
        tweet.user.username, 
        tweet.rawContent, 
        tweet.user.location,
    ]
    tweets.append(data)
    if i > n_tweets:
        break
tweet_df=pd.DataFrame(tweets, columns=['@Username','Tweet', 'Lokasi']
            )
tweet_df.to_csv('sandiaga-uno.csv', index=False)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
